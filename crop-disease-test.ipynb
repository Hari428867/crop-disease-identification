# %%
import os
from PIL import Image

train_dir = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test"

print("✅ Started scanning the train dataset...")
folder_count = 0
total_images = 0
wrong_size_images = []

# Loop through all 39 folders (categories)
for folder_name in os.listdir(train_dir):
    folder_path = os.path.join(train_dir, folder_name)
    if os.path.isdir(folder_path):
        folder_count += 1
        print(f"\n📂 Checking folder {folder_count}: {folder_name}...")
        image_count = 0

        # Loop through each image in the folder
        for image_file in os.listdir(folder_path):
            if image_file.lower().endswith(('.jpg', '.png', '.jpeg')):
                image_path = os.path.join(folder_path, image_file)
                try:
                    img = Image.open(image_path)
                    w, h = img.size
                    image_count += 1
                    total_images += 1

                    # Check resolution
                    if (w, h) != (256, 256):
                        wrong_size_images.append((folder_name, image_file, (w, h)))

                    if image_count % 100 == 0:
                        print(f"   🔹 Processed {image_count} images in {folder_name}...")
                except Exception as e:
                    print(f"⚠️ Error in {image_file}: {e}")

print("\n✅ Scanning completed!")
print(f"📦 Total folders scanned: {folder_count}")
print(f"🖼️ Total images checked: {total_images}")
print(f"❌ Wrong size images found: {len(wrong_size_images)}")

if wrong_size_images:
    print("\nHere are first few wrong-size images:")
    for item in wrong_size_images[:10]:
        print(f"  {item[0]} → {item[1]} (Size: {item[2]})")
else:
    print("🎯 All images are correctly sized (256x256).")
# Out:
# ✅ Started scanning the train dataset...
#
# 📂 Checking folder 1: Apple___Apple_scab...
#
# 📂 Checking folder 2: Apple___Black_rot...
#
# 📂 Checking folder 3: Apple___Cedar_apple_rust...
#
# 📂 Checking folder 4: Apple___healthy...
#    🔹 Processed 100 images in Apple___healthy...
#    🔹 Processed 200 images in Apple___healthy...
#
# 📂 Checking folder 5: Blueberry___healthy...
#    🔹 Processed 100 images in Blueberry___healthy...
#    🔹 Processed 200 images in Blueberry___healthy...
#
# 📂 Checking folder 6: Cherry___healthy...
#    🔹 Processed 100 images in Cherry___healthy...
#
# 📂 Checking folder 7: Cherry___Powdery_mildew...
#    🔹 Processed 100 images in Cherry___Powdery_mildew...
#
# 📂 Checking folder 8: Corn___Cercospora_leaf_spot Gray_leaf_spot...
#
# 📂 Checking folder 9: Corn___Common_rust...
#    🔹 Processed 100 images in Corn___Common_rust...
#
# 📂 Checking folder 10: Corn___healthy...
#    🔹 Processed 100 images in Corn___healthy...
#
# 📂 Checking folder 11: Corn___Northern_Leaf_Blight...
#    🔹 Processed 100 images in Corn___Northern_Leaf_Blight...
#
# 📂 Checking folder 12: Grape___Black_rot...
#    🔹 Processed 100 images in Grape___Black_rot...
#
# 📂 Checking folder 13: Grape___Esca_(Black_Measles)...
#    🔹 Processed 100 images in Grape___Esca_(Black_Measles)...
#    🔹 Processed 200 images in Grape___Esca_(Black_Measles)...
#
# 📂 Checking folder 14: Grape___healthy...
#
# 📂 Checking folder 15: Grape___Leaf_blight_(Isariopsis_Leaf_Spot)...
#    🔹 Processed 100 images in Grape___Leaf_blight_(Isariopsis_Leaf_Spot)...
#
# 📂 Checking folder 16: Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 100 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 200 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 300 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 400 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 500 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 600 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 700 images in Orange___Haunglongbing_(Citrus_greening)...
#    🔹 Processed 800 images in Orange___Haunglongbing_(Citrus_greening)...
#
# 📂 Checking folder 17: Peach___Bacterial_spot...
#    🔹 Processed 100 images in Peach___Bacterial_spot...
#    🔹 Processed 200 images in Peach___Bacterial_spot...
#    🔹 Processed 300 images in Peach___Bacterial_spot...
#
# 📂 Checking folder 18: Peach___healthy...
#
# 📂 Checking folder 19: Pepper,_bell___Bacterial_spot...
#    🔹 Processed 100 images in Pepper,_bell___Bacterial_spot...
#
# 📂 Checking folder 20: Pepper,_bell___healthy...
#    🔹 Processed 100 images in Pepper,_bell___healthy...
#    🔹 Processed 200 images in Pepper,_bell___healthy...
#
# 📂 Checking folder 21: Potato___Early_blight...
#    🔹 Processed 100 images in Potato___Early_blight...
#
# 📂 Checking folder 22: Potato___healthy...
#
# 📂 Checking folder 23: Potato___Late_blight...
#    🔹 Processed 100 images in Potato___Late_blight...
#
# 📂 Checking folder 24: Raspberry___healthy...
#
# 📂 Checking folder 25: Soybean___healthy...
#    🔹 Processed 100 images in Soybean___healthy...
#    🔹 Processed 200 images in Soybean___healthy...
#    🔹 Processed 300 images in Soybean___healthy...
#    🔹 Processed 400 images in Soybean___healthy...
#    🔹 Processed 500 images in Soybean___healthy...
#    🔹 Processed 600 images in Soybean___healthy...
#    🔹 Processed 700 images in Soybean___healthy...
#
# 📂 Checking folder 26: Squash___Powdery_mildew...
#    🔹 Processed 100 images in Squash___Powdery_mildew...
#    🔹 Processed 200 images in Squash___Powdery_mildew...
#
# 📂 Checking folder 27: Strawberry___healthy...
#
# 📂 Checking folder 28: Strawberry___Leaf_scorch...
#    🔹 Processed 100 images in Strawberry___Leaf_scorch...
#
# 📂 Checking folder 29: Tomato___Bacterial_spot...
#    🔹 Processed 100 images in Tomato___Bacterial_spot...
#    🔹 Processed 200 images in Tomato___Bacterial_spot...
#    🔹 Processed 300 images in Tomato___Bacterial_spot...
#
# 📂 Checking folder 30: Tomato___Early_blight...
#    🔹 Processed 100 images in Tomato___Early_blight...
#
# 📂 Checking folder 31: Tomato___healthy...
#    🔹 Processed 100 images in Tomato___healthy...
#    🔹 Processed 200 images in Tomato___healthy...
#
# 📂 Checking folder 32: Tomato___Late_blight...
#    🔹 Processed 100 images in Tomato___Late_blight...
#    🔹 Processed 200 images in Tomato___Late_blight...
#
# 📂 Checking folder 33: Tomato___Leaf_Mold...
#    🔹 Processed 100 images in Tomato___Leaf_Mold...
#
# 📂 Checking folder 34: Tomato___Septoria_leaf_spot...
#    🔹 Processed 100 images in Tomato___Septoria_leaf_spot...
#    🔹 Processed 200 images in Tomato___Septoria_leaf_spot...
#
# 📂 Checking folder 35: Tomato___Spider_mites Two-spotted_spider_mite...
#    🔹 Processed 100 images in Tomato___Spider_mites Two-spotted_spider_mite...
#    🔹 Processed 200 images in Tomato___Spider_mites Two-spotted_spider_mite...
#
# 📂 Checking folder 36: Tomato___Target_Spot...
#    🔹 Processed 100 images in Tomato___Target_Spot...
#    🔹 Processed 200 images in Tomato___Target_Spot...
#
# 📂 Checking folder 37: Tomato___Tomato_mosaic_virus...
#
# 📂 Checking folder 38: Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 100 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 200 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 300 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 400 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 500 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 600 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 700 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#    🔹 Processed 800 images in Tomato___Tomato_Yellow_Leaf_Curl_Virus...
#
# ✅ Scanning completed!
# 📦 Total folders scanned: 38
# 🖼️ Total images checked: 8179
# ❌ Wrong size images found: 0
# 🎯 All images are correctly sized (256x256).

# %%
from PIL import Image
import os
from tqdm import tqdm

train_dir = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test"

non_rgb_images = []

print("🎨 Checking image color modes...")
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        for img_file in os.listdir(class_path):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, img_file)
                try:
                    with Image.open(img_path) as img:
                        if img.mode != "RGB":
                            non_rgb_images.append((class_name, img_file, img.mode))
                except Exception as e:
                    print(f"⚠️ Error opening {img_path}: {e}")

print("\n✅ RGB Check Completed!")
print(f"🖼️ Total non-RGB images found: {len(non_rgb_images)}")

if non_rgb_images:
    print("\nHere are first few examples:")
    for entry in non_rgb_images[:10]:
        print(f"  {entry[0]} → {entry[1]} (Mode: {entry[2]})")
else:
    print("🎯 All images are in RGB format — perfect for training!")
# Out:
# 🎨 Checking image color modes...
#
# ✅ RGB Check Completed!
# 🖼️ Total non-RGB images found: 1
#
# Here are first few examples:
#   Pepper,_bell___healthy → image (1).png (Mode: RGBA)

# %%
from PIL import Image

# Path to the RGBA image
img_path = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test\Pepper,_bell___healthy\image (1).png"

# Open and check mode
img = Image.open(img_path)
print("Before conversion:", img.mode)

# Convert to RGB if needed
if img.mode == "RGBA":
    img = img.convert("RGB")
    # Option 1: overwrite same file
    img.save(img_path)
    # Option 2 (optional): save as new file
    # img.save(img_path.replace(".png", "_rgb.png"))

print("After conversion:", img.mode)
print("✅ Image successfully converted to RGB.")
# Out:
# Before conversion: RGBA
# After conversion: RGB
# ✅ Image successfully converted to RGB.

# %%
from PIL import Image
import os
from tqdm import tqdm

train_dir = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test"

non_rgb_images = []

print("🎨 Checking image color modes...")
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        for img_file in os.listdir(class_path):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, img_file)
                try:
                    with Image.open(img_path) as img:
                        if img.mode != "RGB":
                            non_rgb_images.append((class_name, img_file, img.mode))
                except Exception as e:
                    print(f"⚠️ Error opening {img_path}: {e}")

print("\n✅ RGB Check Completed!")
print(f"🖼️ Total non-RGB images found: {len(non_rgb_images)}")

if non_rgb_images:
    print("\nHere are first few examples:")
    for entry in non_rgb_images[:10]:
        print(f"  {entry[0]} → {entry[1]} (Mode: {entry[2]})")
else:
    print("🎯 All images are in RGB format — perfect for training!")
# Out:
# 🎨 Checking image color modes...
#
# ✅ RGB Check Completed!
# 🖼️ Total non-RGB images found: 0
# 🎯 All images are in RGB format — perfect for training!

# %%
import os
from PIL import Image
from tqdm import tqdm

train_dir = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test"

corrupted_images = []
class_counts = {}

print("🔍 Checking corrupted images and class balance...\n")

for folder in tqdm(os.listdir(train_dir)):
    folder_path = os.path.join(train_dir, folder)
    if not os.path.isdir(folder_path):
        continue

    images = os.listdir(folder_path)
    class_counts[folder] = len(images)

    for img_name in images:
        img_path = os.path.join(folder_path, img_name)
        try:
            img = Image.open(img_path)
            img.verify()  # verifies without loading entire image
        except Exception:
            corrupted_images.append((folder, img_name))

print("\n✅ Scan Completed!")
print(f"📁 Total folders checked: {len(class_counts)}")
print(f"🖼️ Total corrupted images found: {len(corrupted_images)}")

if corrupted_images:
    print("\nHere are some corrupted images:")
    for f, i in corrupted_images[:10]:
        print(f"  {f} → {i}")

print("\n📊 Image Count per Class:")
for cls, count in class_counts.items():
    print(f"  {cls}: {count} images")
# Out:
# 🔍 Checking corrupted images and class balance...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [00:03<00:00, 12.37it/s]
# ✅ Scan Completed!
# 📁 Total folders checked: 38
# 🖼️ Total corrupted images found: 0
#
# 📊 Image Count per Class:
#   Apple___Apple_scab: 95 images
#   Apple___Black_rot: 94 images
#   Apple___Cedar_apple_rust: 42 images
#   Apple___healthy: 248 images
#   Blueberry___healthy: 226 images
#   Cherry___healthy: 129 images
#   Cherry___Powdery_mildew: 159 images
#   Corn___Cercospora_leaf_spot Gray_leaf_spot: 78 images
#   Corn___Common_rust: 180 images
#   Corn___healthy: 175 images
#   Corn___Northern_Leaf_Blight: 149 images
#   Grape___Black_rot: 177 images
#   Grape___Esca_(Black_Measles): 208 images
#   Grape___healthy: 64 images
#   Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 162 images
#   Orange___Haunglongbing_(Citrus_greening): 827 images
#   Peach___Bacterial_spot: 346 images
#   Peach___healthy: 55 images
#   Pepper,_bell___Bacterial_spot: 151 images
#   Pepper,_bell___healthy: 223 images
#   Potato___Early_blight: 150 images
#   Potato___healthy: 24 images
#   Potato___Late_blight: 150 images
#   Raspberry___healthy: 57 images
#   Soybean___healthy: 764 images
#   Squash___Powdery_mildew: 276 images
#   Strawberry___healthy: 69 images
#   Strawberry___Leaf_scorch: 167 images
#   Tomato___Bacterial_spot: 320 images
#   Tomato___Early_blight: 150 images
#   Tomato___healthy: 240 images
#   Tomato___Late_blight: 287 images
#   Tomato___Leaf_Mold: 144 images
#   Tomato___Septoria_leaf_spot: 267 images
#   Tomato___Spider_mites Two-spotted_spider_mite: 252 images
#   Tomato___Target_Spot: 212 images
#   Tomato___Tomato_mosaic_virus: 57 images
#   Tomato___Tomato_Yellow_Leaf_Curl_Virus: 805 images

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Paths
source_dir = r"C:\Users\hp\Downloads\crop-disease-splitted-dataset\test"
target_dir = r"C:\Users\hp\Downloads\crop-disease-preprocessed\test"

def preprocess_image(img):
    # 1. Normalize pixel values (0–1)
    img = img.astype(np.float32) / 255.0
    
    # 2. Histogram equalization (improves contrast)
    img_yuv = cv2.cvtColor((img * 255).astype(np.uint8), cv2.COLOR_RGB2YCrCb)
    img_yuv[:, :, 0] = cv2.equalizeHist(img_yuv[:, :, 0])
    img_eq = cv2.cvtColor(img_yuv, cv2.COLOR_YCrCb2RGB)
    
    # 3. Optional: Gaussian blur (reduces small noise)
    img_blur = cv2.GaussianBlur(img_eq, (3, 3), 0)
    
    return img_blur

print("⚙️ Starting preprocessing of images...\n")

# Loop through each class folder
for folder in tqdm(os.listdir(source_dir)):
    src_folder = os.path.join(source_dir, folder)
    dst_folder = os.path.join(target_dir, folder)
    os.makedirs(dst_folder, exist_ok=True)
    
    for img_name in os.listdir(src_folder):
        img_path = os.path.join(src_folder, img_name)
        save_path = os.path.join(dst_folder, img_name)

        try:
            img = cv2.imread(img_path)
            if img is None:
                continue
            
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            processed_img = preprocess_image(img)

            # Save back as jpg (uint8)
            cv2.imwrite(save_path, cv2.cvtColor(processed_img, cv2.COLOR_RGB2BGR))
        except Exception as e:
            print(f"❌ Error on {img_name}: {e}")

print("\n✅ Preprocessing completed and saved to:")
print(target_dir)
# Out:
# ⚙️ Starting preprocessing of images...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [01:06<00:00,  1.75s/it]
# ✅ Preprocessing completed and saved to:
# C:\Users\hp\Downloads\crop-disease-preprocessed\test

# %%
import os
import cv2
import numpy as np
import polars as pl
from tqdm import tqdm
from skimage.feature import graycomatrix, graycoprops

# Paths
data_dir = r"C:\Users\hp\Downloads\crop-disease-preprocessed\test"
output_file = r"C:\Users\hp\Downloads\crop_test_features.parquet"

def extract_features(img):
    # Convert to grayscale for texture features
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    # --- Color features ---
    mean = np.mean(img, axis=(0,1))
    std = np.std(img, axis=(0,1))
    
    # --- Texture features (GLCM) ---
    glcm = graycomatrix(gray, distances=[1], angles=[0], symmetric=True, normed=True)
    contrast = graycoprops(glcm, 'contrast')[0,0]
    correlation = graycoprops(glcm, 'correlation')[0,0]
    energy = graycoprops(glcm, 'energy')[0,0]
    homogeneity = graycoprops(glcm, 'homogeneity')[0,0]
    
    return np.hstack([mean, std, contrast, correlation, energy, homogeneity])

# Store all features
records = []

print("⚙️ Extracting color & texture features...\n")

for folder in tqdm(os.listdir(data_dir)):
    folder_path = os.path.join(data_dir, folder)
    if not os.path.isdir(folder_path):
        continue

    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        try:
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            feats = extract_features(img)
            records.append([folder, *feats])
        except:
            pass

# Convert to Polars DataFrame
columns = [
    "label", 
    "mean_r", "mean_g", "mean_b",
    "std_r", "std_g", "std_b",
    "contrast", "correlation", "energy", "homogeneity"
]
df = pl.DataFrame(records, schema=columns)

# Save as parquet file
df.write_parquet(output_file)

print(f"\n✅ Features extracted and saved to: {output_file}")
print(f"Total samples: {df.shape[0]}")
# Out:
# ⚙️ Extracting color & texture features...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [04:27<00:00,  7.05s/it]
# ✅ Features extracted and saved to: C:\Users\hp\Downloads\crop_test_features.parquet
# Total samples: 8179
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\functools.py:889: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
import polars as pl

df = pl.read_parquet(r"C:\Users\hp\Downloads\crop_test_features.parquet")
print(df.head())        # show first 5 rows
print(df.shape)         # see number of rows and columns
# Out:
# shape: (5, 11)
# ┌────────────────────┬────────────┬────────────┬────────────┬───┬────────────┬─────────────┬──────────┬─────────────┐
# │ label              ┆ mean_r     ┆ mean_g     ┆ mean_b     ┆ … ┆ contrast   ┆ correlation ┆ energy   ┆ homogeneity │
# │ ---                ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---         ┆ ---      ┆ ---         │
# │ str                ┆ f64        ┆ f64        ┆ f64        ┆   ┆ f64        ┆ f64         ┆ f64      ┆ f64         │
# ╞════════════════════╪════════════╪════════════╪════════════╪═══╪════════════╪═════════════╪══════════╪═════════════╡
# │ Apple___Apple_scab ┆ 120.329803 ┆ 135.235199 ┆ 113.152206 ┆ … ┆ 93.426777  ┆ 0.990966    ┆ 0.01989  ┆ 0.296468    │
# │ Apple___Apple_scab ┆ 119.447479 ┆ 136.083176 ┆ 112.797424 ┆ … ┆ 218.429795 ┆ 0.9758      ┆ 0.014549 ┆ 0.156364    │
# │ Apple___Apple_scab ┆ 123.136963 ┆ 131.548782 ┆ 123.242188 ┆ … ┆ 172.03125  ┆ 0.980519    ┆ 0.013113 ┆ 0.161862    │
# │ Apple___Apple_scab ┆ 126.904526 ┆ 130.665237 ┆ 127.111526 ┆ … ┆ 178.694056 ┆ 0.981638    ┆ 0.012316 ┆ 0.14534     │
# │ Apple___Apple_scab ┆ 120.622681 ┆ 134.94989  ┆ 124.576843 ┆ … ┆ 144.737806 ┆ 0.985291    ┆ 0.012232 ┆ 0.144364    │
# └────────────────────┴────────────┴────────────┴────────────┴───┴────────────┴─────────────┴──────────┴─────────────┘
# (8179, 11)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load features
test_df = pd.read_parquet(r"C:\Users\hp\Downloads\crop_test_features.parquet")
test_df.head()
# Out:
#                 label      mean_r      mean_g      mean_b      std_r  \
# 0  Apple___Apple_scab  120.329803  135.235199  113.152206  74.652528
# 1  Apple___Apple_scab  119.447479  136.083176  112.797424  75.521789
# 2  Apple___Apple_scab  123.136963  131.548782  123.242188  71.070947
# 3  Apple___Apple_scab  126.904526  130.665237  127.111526  71.719717
# 4  Apple___Apple_scab  120.622681  134.949890  124.576843  76.320193
#
#        std_g      std_b    contrast  correlation    energy  homogeneity
# 0  70.439579  83.908834   93.426777     0.990966  0.019890     0.296468
# 1  61.555788  85.206433  218.429795     0.975800  0.014549     0.156364
# 2  62.804712  79.906512  172.031250     0.980519  0.013113     0.161862
# 3  67.149860  82.291223  178.694056     0.981638  0.012316     0.145340
# 4  65.429008  82.172813  144.737806     0.985291  0.012232     0.144364

# %%
test_df.columns
# Out:
# Index(['label', 'mean_r', 'mean_g', 'mean_b', 'std_r', 'std_g', 'std_b',
#        'contrast', 'correlation', 'energy', 'homogeneity', 'label_encoded'],
#       dtype='object')

# %%
# Encode labels
le = LabelEncoder()
test_df['label_encoded'] = le.fit_transform(test_df['label'])

# Features and target
X_test = test_df.drop(['label', 'label_encoded'], axis=1)
y_test = test_df['label_encoded']

# %%
import joblib

# Load the trained SVM model
svm = joblib.load(r"C:\Users\hp\Downloads\crop-disease_svm_trained_model.pkl")
print("✅ Model loaded successfully")
# Out:
# ✅ Model loaded successfully

# %%
y_test_pred = svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Accuracy
acc = accuracy_score(y_test, y_test_pred)
print(f"✅ Test data Accuracy: {acc*100:.2f}%")

# Classification report
print("\n📊 Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# ✅ Test data Accuracy: 48.93%
#
# 📊 Classification Report:
#                                                precision    recall  f1-score   support
#
#                            Apple___Apple_scab       0.27      0.42      0.33        95
#                             Apple___Black_rot       0.19      0.40      0.26        94
#                      Apple___Cedar_apple_rust       0.08      0.40      0.13        42
#                               Apple___healthy       0.54      0.58      0.56       248
#                           Blueberry___healthy       0.50      0.46      0.48       226
#                       Cherry___Powdery_mildew       0.32      0.35      0.33       159
#                              Cherry___healthy       0.61      0.85      0.71       129
#    Corn___Cercospora_leaf_spot Gray_leaf_spot       0.36      0.54      0.43        78
#                            Corn___Common_rust       0.90      0.90      0.90       180
#                   Corn___Northern_Leaf_Blight       0.28      0.37      0.32       149
#                                Corn___healthy       0.82      0.96      0.88       175
#                             Grape___Black_rot       0.26      0.51      0.35       177
#                  Grape___Esca_(Black_Measles)       0.29      0.28      0.29       208
#    Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.50      0.74      0.59       162
#                               Grape___healthy       0.30      0.58      0.39        64
#      Orange___Haunglongbing_(Citrus_greening)       0.77      0.67      0.72       827
#                        Peach___Bacterial_spot       0.33      0.30      0.31       346
#                               Peach___healthy       0.22      0.93      0.36        55
#                 Pepper,_bell___Bacterial_spot       0.17      0.16      0.17       151
#                        Pepper,_bell___healthy       0.47      0.28      0.35       223
#                         Potato___Early_blight       0.49      0.65      0.56       150
#                          Potato___Late_blight       0.27      0.39      0.32       150
#                              Potato___healthy       0.20      0.71      0.31        24
#                           Raspberry___healthy       0.23      0.58      0.33        57
#                             Soybean___healthy       0.92      0.72      0.81       764
#                       Squash___Powdery_mildew       0.64      0.46      0.54       276
#                      Strawberry___Leaf_scorch       0.67      0.68      0.68       167
#                          Strawberry___healthy       0.38      0.78      0.51        69
#                       Tomato___Bacterial_spot       0.55      0.59      0.57       320
#                         Tomato___Early_blight       0.22      0.22      0.22       150
#                          Tomato___Late_blight       0.48      0.21      0.29       287
#                            Tomato___Leaf_Mold       0.44      0.14      0.21       144
#                   Tomato___Septoria_leaf_spot       0.33      0.10      0.16       267
# Tomato___Spider_mites Two-spotted_spider_mite       0.45      0.48      0.46       252
#                          Tomato___Target_Spot       0.38      0.50      0.43       212
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.57      0.14      0.23       805
#                  Tomato___Tomato_mosaic_virus       0.40      0.88      0.55        57
#                              Tomato___healthy       0.72      0.83      0.77       240
#
#                                      accuracy                           0.49      8179
#                                     macro avg       0.43      0.52      0.44      8179
#                                  weighted avg       0.54      0.49      0.48      8179
